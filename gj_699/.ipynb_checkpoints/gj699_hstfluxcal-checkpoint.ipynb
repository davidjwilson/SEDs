# %% [markdown]
# Looking at the HST data for GJ 699.

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import astropy.io.fits as fits
import os
from scipy.io.idl import readsav
from astropy.table import Table
from astropy.io import ascii
import astropy.units as u
import astropy.constants as const
from astropy.modeling import models, fitting
from craftroom import resample
from scipy.interpolate import interp1d
from astropy.convolution import convolve, Box1DKernel



# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
path = '/home/david/work/muscles/MegaMUSCLES/GJ_699/HST/STIS/'

# %%
x1ds =  glob.glob(path+'*x1d.fits')

for x in x1ds:
    hdr = fits.getheader(x,0)
    print(hdr['ROOTNAME'], hdr['OPT_ELEM'])
# Out:
# odlm24020 G230L
# odlm22030 G140L
# odlm24030 G140M
# odlm24040 G140M
# odlm22010 G140L
# odlm22020 G140L
# odlm24050 G140M

# %%
"""for x in x1ds:
    hdr = fits.getheader(x,0)
    print(hdr['ROOTNAME'], hdr['OPT_ELEM'])
    data = fits.getdata(x,1)[0]
    plt.step(data['WAVELENGTH'], data['FLUX'], where='mid')
    plt.step(data['WAVELENGTH'], data['ERROR'], where='mid')
    plt.show()"""
# Out:
# "for x in x1ds:\n    hdr = fits.getheader(x,0)\n    print(hdr['ROOTNAME'], hdr['OPT_ELEM'])\n    data = fits.getdata(x,1)[0]\n    plt.step(data['WAVELENGTH'], data['FLUX'], where='mid')\n    plt.step(data['WAVELENGTH'], data['ERROR'], where='mid')\n    plt.show()"

# %% [markdown]
# Checking notes, I've already processed the G140L and G140M data:

# %%
fuv = glob.glob('STIS/*140*ecsv')
for sp in fuv:
    data = Table.read(sp)
    plt.step(data['WAVELENGTH'], data['FLUX'], where='mid')
    plt.step(data['WAVELENGTH'], data['ERROR'], where='mid')
fdata = Table.read(fuv[0])

# %%
nuv = '/home/david/work/muscles/MegaMUSCLES/GJ_699/HST/STIS/odlm24020_x1d.fits'
ndata = fits.getdata(nuv,1)[0]
w, f, e, dq = ndata['WAVELENGTH'], ndata['FLUX'], ndata['ERROR'], ndata['DQ']  
#smooth = 2
#f = convolve(f,Box1DKernel(smooth))
#e = convolve(e,Box1DKernel(smooth))/(smooth**0.5)

#plt.step(w, f, where='mid')
#plt.step(w, e, where='mid')
#plt.step(w[dq==0], f[dq==0], where='mid')

plt.xlim(1600)
plt.ylim(-0.1e-14, 3e-15)
plt.axhline(0, ls='--', c='0.5')

# %% [markdown]
# Ok, looks like no useful overlap with the fuv data. What about galex- no Galex photometry available. G430L?

# %%
g430lpath = glob.glob(path+'*sx1.fits')
odata = fits.getdata(g430lpath[0],1)[0]
plt.step(odata['WAVELENGTH'], odata['FLUX'], where='mid')
plt.step(odata['WAVELENGTH'], odata['ERROR'], where='mid')
plt.axhline(0, ls='--', c='0.5')
plt.show()
plt.plot(odata['WAVELENGTH'], odata['FLUX']/odata['ERROR'])
plt.axhline(1, ls='--', c='0.5')
plt.xscale('log')
plt.yscale('log')
#ca =[ 3933.6614, 3968.4673] #no ca detected
#[plt.axvline(line, c='r') for line in ca]
#plt.xlim(3900, 4100)
#plt.ylim(-0.1e-12, 0.1e-12)

# %%
plt.step(odata['WAVELENGTH'][odata['DQ']==0], odata['FLUX'][odata['DQ']==0], where='mid')
plt.step(ndata['WAVELENGTH'][ndata['DQ']==0], ndata['FLUX'][ndata['DQ']==0], where='mid')
plt.step(fdata['WAVELENGTH'], fdata['FLUX'], where='mid')
plt.axhline(0, ls='--', c='0.5')
plt.xscale('log')
plt.yscale('log')
plt.ylim(1e-17)
#print(ndata['WAVELENGTH'][-1], odata['WAVELENGTH'][0])
#plt.xlim(1550,1800 )
# Out:
# (1e-17, 1.7903951101433058e-12)

# %% [markdown]
# FUV v NUV

# %%
#w0, w1 = ndata['WAVELENGTH'][0], fdata['WAVELENGTH'][-1]
ints = []
w0, w1 = 1630, fdata['WAVELENGTH'][-1]
for i in [0,1]:
    if i == 0:
        dt = fdata
    else:
        dt = ndata
    w, f, e, dq = dt['WAVELENGTH'], dt['FLUX'], dt['ERROR'], dt['DQ']
    mask = (w > w0) & (w < w1)# & (dq ==0)
    wi, fi, ei = w[mask], f[mask], e[mask]
    plt.step(wi, fi, where='mid')
    plt.step(wi, ei, where='mid')
    fint = np.trapz(fi, wi)
    eint = np.sum(ei[1:]**2*np.diff(wi)**2)**0.5 
    print(fint, eint)
    ints.append(fint)
plt.ylim(-0.1e-13, 0.1e-13)
print(ints[0]/ints[1])
# Out:
# 9.496036710588472e-15 5.448265006014494e-16
# 2.1043271135965537e-14 1.2242087843536537e-14
# 0.45126238450440237

# %%
ratio  = []
ws = []
for i, wi in enumerate(ndata['WAVELENGTH'][::-1]):
    mask = (ndata['WAVELENGTH'] > wi) & (ndata['WAVELENGTH'] < fdata['WAVELENGTH'][-1]) 
    fint = np.trapz(ndata['FLUX'][mask], ndata['WAVELENGTH'][mask])
    eint = np.sum(ndata['ERROR'][mask][1:]**2*np.diff(ndata['WAVELENGTH'][mask])**2)**0.5
    ratio.append(abs(fint)/abs(eint))
    ws.append(wi)
plt.plot(w[::-1], ratio)
plt.axhline(1, ls='--', c='0.5')
# Out:
# /home/david/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys

# %% [markdown]
# NUV to OPT

# %%
ints = []
w0, w1 = odata['WAVELENGTH'][0], ndata['WAVELENGTH'][-1]
for i in [0,1]:
    if i == 0:
        dt = ndata
    else:
        dt = odata
    w, f, e, dq = dt['WAVELENGTH'], dt['FLUX'], dt['ERROR'], dt['DQ']
    mask = (w > w0) & (w < w1)# & (dq ==0)
    wi, fi, ei = w[mask], f[mask], e[mask]
    plt.step(wi, fi, where='mid')
  #  plt.step(wi, ei, where='mid')
    fint = np.trapz(fi, wi)
    eint = np.sum(ei[1:]**2*np.diff(wi)**2)**0.5 
    print(fint, eint)
    ints.append(fint)
plt.ylim(-0.1e-13, 0.1e-13)
print(ints[0]/ints[1])
# Out:
# 3.748421750482594e-13 8.328968288639138e-15
# 1.8135300986546423e-13 3.1442910064704688e-12
# 2.0669200656020768

# %% [markdown]
# Ok so STIS opt is useless for normalisation. Get Phoenix model? Compare with photometery. Did we get a COS NUV spectrum? No. Need to check FUV against flare-free COS spectrum, waiting on KF.We have it now!

# %%
"""cospath ='/home/david/work/muscles/MegaMUSCLES/GJ_699/HST/COS/'
cx1ds =  glob.glob(cospath+'*x1d.fits')
#print(cx1ds)
for x in cx1ds:
    hdr = fits.getheader(x,0)
    print(hdr['ROOTNAME'], hdr['OPT_ELEM'])"""
# Out:
# "cospath ='/home/david/work/muscles/MegaMUSCLES/GJ_699/HST/COS/'\ncx1ds =  glob.glob(cospath+'*x1d.fits')\n#print(cx1ds)\nfor x in cx1ds:\n    hdr = fits.getheader(x,0)\n    print(hdr['ROOTNAME'], hdr['OPT_ELEM'])"

# %%
cosspecs = glob.glob('COS/*24may*.sav')
cosspecs
# Out:
# ['COS/GJ699_flare_G130M_Mm1_NOSCL_24may2019.sav',
#  'COS/GJ699_quiesc_G130M_Mm1_NOSCL_24may2019.sav']

# %%
#for sp in cosspecs:
    #data= readsav(sp)
    #plt.plot(data['wave'], data['flux'])
cdata = readsav(cosspecs[1])
plt.step(cdata['wave'], cdata['flux'], where='mid')
#plt.step(cdata['wave'], cdata['err'], where='mid')
plt.step(fdata['WAVELENGTH'], fdata['FLUX'])
plt.xlim(fdata['WAVELENGTH'][0], cdata['wave'][-1])
plt.ylim(-0.1e-14, 1e-14)
plt.axhline(0, ls='--', c='0.5')
plt.axvline(1207)
plt.axvline(1222)

# %%
ints = []
w0, w1 = fdata['WAVELENGTH'][0], cdata['wave'][-1]
for i in [0,1]:
    if i == 0:
        dt = fdata
        w, f, e = dt['WAVELENGTH'], dt['FLUX'], dt['ERROR']
        mask = (w> w0) & (w< 1207) | (w > 1222) & (w< 1301) | (w > 1307) & (w < w1)# & (dq ==0)
        wi, fi, ei = w[mask], f[mask], e[mask]
        wn= wi)
        
    else:
        dt = cdata
        w, f, e = dt['wave'], dt['flux'], dt['err']
        mask = (w> w0) & (w< 1207) | (w > 1222) & (w< 1301) | (w > 1307) & (w < w1)# & (dq ==0)
        wi, fi, ei = w[mask], f[mask], e[mask]
        #wi, fi, ei = resample.bintogrid(wi, fi, newx=wn, unc=ei)
        #fi = interp1d(wi, fi, fill_value='extrapolate')(wn)
        #ei = interp1d(wi, ei, fill_value='extrapolate')(wn)
    plt.step(wi, fi, where='mid')
 #   plt.step(wi, ei, where='mid')
    fint = np.trapz(fi, wi)
    eint = np.sum(ei[1:]**2*np.diff(wi)**2)**0.5 
    print(fint, eint)
    ints.append(fint)
#plt.ylim(-0.1e-13, 0.1e-13)
plt.axhline(0, ls='--', c='0.5')
print(ints[0]/ints[1])
# Out:
# 4.670599721338233e-15 3.647089713348519e-16
# 5.865909077071292e-15 2.053843508525459e-16
# 0.7962277730479504

# %%
#plt.step(cdata['wave'], cdata['flux'], where='mid')
#plt.step(fdata['WAVELENGTH'], fdata['FLUX'])
wc1, fc1 = resample.bintogrid(cdata['wave'], cdata['flux'], dx=1)
wf1, ff1 = resample.bintogrid(fdata['WAVELENGTH'], fdata['FLUX'], dx=1)
plt.step(wc1, fc1, where='mid')
plt.step(wf1, ff1, where='mid')
#plt.xlim(fdata['WAVELENGTH'][0], cdata['wave'][-1])
plt.xlim(1340, 1380)
plt.ylim(1e-19, 1e-15)
#plt.xscale('log')
plt.yscale('log')
print(np.trapz(fdata['FLUX'], fdata['WAVELENGTH']))
print(np.trapz(cdata['FLUX'], cdata['wave']))
# Out:
# 9.162429105840542e-13
# 3.347132786871867e-14

# %% [markdown]
# Think I can just stick it in the code and see what happens? Something's up with the stis fuv.

# %%
#hdul = fits.open('test_files/components/hlsp_muscles_hst_stis_gj699_g140l_v2_component-spec.fits')
#hdat = hdul[1].data
hdat = Table.read('test_files/components/hlsp_muscles_hst_stis_gj699_g140l_v2_component-spec.ecsv')
hdat.meta['NORMFAC']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-5ee968f4f937> in <module>()
#       1 #hdul = fits.open('test_files/components/hlsp_muscles_hst_stis_gj699_g140l_v2_component-spec.fits')
#       2 #hdat = hdul[1].data
# ----> 3 hdat = Table.read('test_files/components/hlsp_muscles_hst_stis_gj699_g140l_v2_component-spec.ecsv')
#       4 hdat.meta['NORMFAC']
#
# /home/david/anaconda3/lib/python3.7/site-packages/astropy/table/connect.py in __call__(self, *args, **kwargs)
#      50     def __call__(self, *args, **kwargs):
#      51         cls = self._cls
# ---> 52         out = registry.read(cls, *args, **kwargs)
#      53
#      54         # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#
# /home/david/anaconda3/lib/python3.7/site-packages/astropy/io/registry.py in read(cls, format, *args, **kwargs)
#     506                     try:
#     507                         ctx = get_readable_fileobj(args[0], encoding='binary')
# --> 508                         fileobj = ctx.__enter__()
#     509                     except OSError:
#     510                         raise
#
# /home/david/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /home/david/anaconda3/lib/python3.7/site-packages/astropy/utils/data.py in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers)
#     235                 timeout=remote_timeout, sources=sources,
#     236                 http_headers=http_headers)
# --> 237         fileobj = io.FileIO(name_or_obj, 'r')
#     238         if is_url and not cache:
#     239             delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_files/components/hlsp_muscles_hst_stis_gj699_g140l_v2_component-spec.ecsv'

# %%
plt.plot(hdat['WAVELENGTH'], hdat['FLUX'])
#plt.plot(fdata['WAVELENGTH'], fdata['FLUX']/47)
plt.xlim(1340, 1380)
plt.ylim(1e-21, 1e-15)
plt.yscale('log')
testdat = Table.read('../common/quicksaves/GJ699_1A_basic.ecsv')
plt.plot(testdat['WAVELENGTH'], testdat['FLUX'])

# %%
hdul[0].header['NORMFAC']
