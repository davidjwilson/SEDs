# %% [markdown]
# Barnard's star has finally been observed with TESS.

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.table import Table
from astropy.io import ascii
from astropy.convolution import convolve, Box1DKernel
from scipy.interpolate import interp1d

import astropy.units as u
from astropy import time, coordinates as coord
import astropy.constants as const
from astropy.modeling import models, fitting
from matplotlib.gridspec import GridSpec
import lightkurve as lk

#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
search_result = lk.search_lightcurve('TIC 325554331')
search_result
# Out:
# SearchResult containing 2 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 80 2024   SPOC      20   325554331      0.0
#   1 TESS Sector 80 2024   SPOC     120   325554331      0.0

# %%
lc = search_result[1].download(download_dir='tess/')

# %%
lcn = lc.normalize().remove_outliers(sigma=7)
lcn.scatter()
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Normalized Flux'>

# %%
# plt.plot(lcn.time.value, lc.flux)
plt.scatter(lcn.time.value, lcn.flux, s=5)
plt.xlim(3501, 3502)
# Out:
# (3501.0, 3502.0)

# %%
1000/1.19
# Out:
# 840.3361344537816
