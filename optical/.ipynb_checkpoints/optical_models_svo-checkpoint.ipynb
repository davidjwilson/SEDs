# %% [markdown]
# Getting the btsettl PHOENIX models for the MM stars. Making new ones with the SVO models

# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from scipy.interpolate import interp1d
from scipy.io.idl import readsav
from astropy.table import Table
from astropy.io import ascii
import astropy.units as u
from scipy.optimize import leastsq
import astropy.constants as const
from astropy.convolution import convolve, Box1DKernel
from astropy.modeling import models, fitting
import prepare_phoenix_svo as pp

#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %%
params = Table.read('stellar_parameters.csv')

# %%
params
# Out:
# <Table length=12>
#   Target    RAJ2000    DEJ2000     Jmag  ... Teff_e parallax   distance  P_rot_d
#   str10     float64    float64   float64 ... int64  float64    float64   float64
# ---------- ---------- ---------- ------- ... ------ -------- ----------- -------
#    GJ 1132 153.716027 -47.156796   9.245 ...     72    83.07 12.03804021  126.59
#    GJ 676A 262.546646 -51.637012   6.711 ...     94    63.07 15.85539876    41.2
#     GJ 15A   4.594036  44.022842   5.252 ...     12   280.74 3.562014676    -1.0
#     GJ 649 254.536873   25.74423   6.448 ...     41    96.38  10.3755966    -1.0
#     GJ 163  62.315307 -53.373737   7.948 ...     76    66.59 15.01726986    61.0
#     GJ 849 332.417906  -4.640765    6.51 ...     70   113.25 8.830022075    39.2
#     GJ 674 262.166316  -46.89513   5.711 ...     59   220.24 4.540501271    32.9
#     GJ 699 269.452044   4.694597   5.244 ...     17   548.31 1.823785815   130.4
#    L 980-5 215.313034  -1.122204   8.948 ...     74    74.66 13.39405304   92.23
#   LHS 2686 197.552869  47.755291   9.584 ...     70     76.1 13.14060447    28.8
#     GJ 729 282.455404 -23.836149   6.222 ...     68   336.72 2.969826562    2.84
# Trappist-1 346.622013  -5.041274  11.354 ...     71    82.58 12.10946961     3.3

# %%
G = const.G
M = const.M_sun.to(u.kg)
R = const.R_sun.to(u.m)
for m, r, t in zip(params['Mass'], params['Radius'], params['Teff']):
    g = G*(m*M)/(r*R)**2
    g =  g.to(u.cm/u.s**2)
    print(t,np.log10(g.value))
    #print(logg)
# Out:
# 3196 5.060992437402149
# 4014 4.65331360755076
# 3601 4.861538718661559
# 3621 4.707209872123922
# 3460 4.822076034503119
# 3492 4.772484619083325
# 3404 4.87082792887964
# 3223 5.101210290261985
# 3278 5.007675594849958
# 3119 5.113824503742217
# 3248 5.083980902336978
# 2619 5.292907918630075

# %%
###### pp.make_phoenix_spectrum(star, save_path, repo, star_params, save_ecsv=False, plot=False)
#star_params = {'Teff': 2628, 'logg': 5.21, 'FeH': 0.00, 'aM': 0, 'radius':1.16*u.R_jup, 'distance':12.43*u.pc}
G = const.G
M = const.M_sun.to(u.kg)
R = const.R_sun.to(u.m)
save_path = 'interpolated_models/'
# repo = '/media/david/5tb_storage1/muscles/btsettl_models/'
repo = '/media/david/1tb_storage1/emergency_data/mega_muscles/data-vacuum/'
for row in params:
    star = row['Target']
    star = star.replace(' ', '')
    if star == 'Trappist-1':
        star = '2MASS-J23062928-0502285'
#     if star != 'Trappist-1':# and star == 'GJ 15A':
    g = (G*(row['Mass']*M)/(row['Radius']*R)**2).to(u.cm/u.s**2)
    star_params = {'Teff': row['Teff'], 'logg': np.log10(g.value), 'FeH': 0.00, 'aM': 0, 'Radius':row['Radius']*u.R_sun, 'Distance':row['distance']*u.pc}

    pp.make_phoenix_spectrum(star, save_path, repo, star_params, save_ecsv=True, plot=True)
# Out:
# [{'Teff': 3100, 'logg': 5.0, 'FeH': 0.0, 'aM': 0.0}, {'Teff': 3100, 'logg': 5.5, 'FeH': 0.0, 'aM': 0.0}, {'Teff': 3200, 'logg': 5.0, 'FeH': 0.0, 'aM': 0.0}, {'Teff': 3200, 'logg': 5.5, 'FeH': 0.0, 'aM': 0.0}]
# ---------------------------------------------------------------------------
# RepresenterError                          Traceback (most recent call last)
# <ipython-input-5-7808d2b00de5> in <module>
#      13     star_params = {'Teff': row['Teff'], 'logg': np.log10(g.value), 'FeH': 0.00, 'aM': 0, 'Radius':row['Radius']*u.R_sun, 'Distance':row['distance']*u.pc}
#      14
# ---> 15     pp.make_phoenix_spectrum(star, save_path, repo, star_params, save_ecsv=True, plot=True)
#
# ~/work/muscles/SEDs/optical/prepare_phoenix_svo.py in make_phoenix_spectrum(star, save_path, repo, star_params, save_ecsv, plot, to_vac)
#     213         wavelength, flux = air_to_vac(wavelength, flux)
#     214     if save_ecsv:
# --> 215         save_to_ecsv(star, wavelength, flux, save_path, star_params, normfac)
#     216     if plot == True:
#     217         plot_spectrum(wavelength, flux, star, normfac)
#
# ~/work/muscles/SEDs/optical/prepare_phoenix_svo.py in save_to_ecsv(star, wavelength, flux, save_path, star_params, normfac)
#     137     star = star.replace(' ', '')
#     138     #ascii.write(savedat, save_path+star+'_phoenix_interpolated.ecsv', overwrite=True, format='ecsv')
# --> 139     savedat.write(save_path+star+'_phoenix_interpolated.ecsv', overwrite=True, format='ascii.ecsv')
#     140
#     141 def plot_spectrum(wavelength, flux, star, normfac):
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/table/connect.py in __call__(self, serialize_method, *args, **kwargs)
#     124         instance = self._instance
#     125         with serialize_method_as(instance, serialize_method):
# --> 126             registry.write(instance, *args, **kwargs)
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/io/registry.py in write(data, format, *args, **kwargs)
#     561
#     562     writer = get_writer(format, data.__class__)
# --> 563     writer(data, *args, **kwargs)
#     564
#     565
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/io/ascii/connect.py in io_write(format, table, filename, **kwargs)
#      24         format = re.sub(r'^ascii\.', '', format)
#      25         kwargs['format'] = format
# ---> 26     return write(table, filename, **kwargs)
#      27
#      28
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/io/ascii/ui.py in write(table, output, format, Writer, fast_writer, overwrite, **kwargs)
#     852         return
#     853
# --> 854     lines = writer.write(table)
#     855
#     856     # Write the lines to output
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/io/ascii/core.py in write(self, table)
#    1413         # Write header and data to lines list
#    1414         lines = []
# -> 1415         self.write_header(lines, table.meta)
#    1416         self.data.write(lines)
#    1417
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/io/ascii/core.py in write_header(self, lines, meta)
#    1372     def write_header(self, lines, meta):
#    1373         self.header.write_comments(lines, meta)
# -> 1374         self.header.write(lines)
#    1375
#    1376     def write(self, table):
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/io/ascii/ecsv.py in write(self, lines)
#      75         header_yaml_lines = ([f'%ECSV {ECSV_VERSION}',
#      76                               '---']
# ---> 77                              + meta.get_yaml_from_header(header))
#      78
#      79         lines.extend([self.write_comment + line for line in header_yaml_lines])
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/table/meta.py in get_yaml_from_header(header)
#     289
#     290     lines = yaml.dump(header, default_flow_style=None,
# --> 291                       Dumper=TableDumper, width=130).splitlines()
#     292     return lines
#     293
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/yaml/__init__.py in dump(data, stream, Dumper, **kwds)
#     288     If stream is None, return the produced string instead.
#     289     """
# --> 290     return dump_all([data], stream, Dumper=Dumper, **kwds)
#     291
#     292 def safe_dump_all(documents, stream=None, **kwds):
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/yaml/__init__.py in dump_all(documents, stream, Dumper, default_style, default_flow_style, canonical, indent, width, allow_unicode, line_break, encoding, explicit_start, explicit_end, version, tags, sort_keys)
#     276         dumper.open()
#     277         for data in documents:
# --> 278             dumper.represent(data)
#     279         dumper.close()
#     280     finally:
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/yaml/representer.py in represent(self, data)
#      25
#      26     def represent(self, data):
# ---> 27         node = self.represent_data(data)
#      28         self.serialize(node)
#      29         self.represented_objects = {}
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/yaml/representer.py in represent_data(self, data)
#      46         data_types = type(data).__mro__
#      47         if data_types[0] in self.yaml_representers:
# ---> 48             node = self.yaml_representers[data_types[0]](self, data)
#      49         else:
#      50             for data_type in data_types:
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/yaml/representer.py in represent_dict(self, data)
#     205
#     206     def represent_dict(self, data):
# --> 207         return self.represent_mapping('tag:yaml.org,2002:map', data)
#     208
#     209     def represent_set(self, data):
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/table/meta.py in represent_mapping(self, tag, mapping, flow_style)
#     268             for item_key, item_value in mapping:
#     269                 node_key = self.represent_data(item_key)
# --> 270                 node_value = self.represent_data(item_value)
#     271                 if not (isinstance(node_key, yaml.ScalarNode) and not node_key.style):
#     272                     best_style = False
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/yaml/representer.py in represent_data(self, data)
#      46         data_types = type(data).__mro__
#      47         if data_types[0] in self.yaml_representers:
# ---> 48             node = self.yaml_representers[data_types[0]](self, data)
#      49         else:
#      50             for data_type in data_types:
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/yaml/representer.py in represent_dict(self, data)
#     205
#     206     def represent_dict(self, data):
# --> 207         return self.represent_mapping('tag:yaml.org,2002:map', data)
#     208
#     209     def represent_set(self, data):
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/astropy/table/meta.py in represent_mapping(self, tag, mapping, flow_style)
#     268             for item_key, item_value in mapping:
#     269                 node_key = self.represent_data(item_key)
# --> 270                 node_value = self.represent_data(item_value)
#     271                 if not (isinstance(node_key, yaml.ScalarNode) and not node_key.style):
#     272                     best_style = False
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/yaml/representer.py in represent_data(self, data)
#      56                     node = self.yaml_multi_representers[None](self, data)
#      57                 elif None in self.yaml_representers:
# ---> 58                     node = self.yaml_representers[None](self, data)
#      59                 else:
#      60                     node = ScalarNode(None, str(data))
#
# ~/anaconda3/envs/astroconda/lib/python3.6/site-packages/yaml/representer.py in represent_undefined(self, data)
#     229
#     230     def represent_undefined(self, data):
# --> 231         raise RepresenterError("cannot represent an object", data)
#     232
#     233 SafeRepresenter.add_representer(type(None),
#
# RepresenterError: ('cannot represent an object', 'GJ 1132')

# %%
glob.glob('interpolated_models/*ecsv')
# Out:
# ['interpolated_models/GJ849_phoenix_interpolated.ecsv',
#  'interpolated_models/GJ674_phoenix_interpolated.ecsv',
#  'interpolated_models/GJ676A_phoenix_interpolated.ecsv',
#  'interpolated_models/GJ729_phoenix_interpolated.ecsv',
#  'interpolated_models/GJ649_phoenix_interpolated.ecsv',
#  'interpolated_models/GJ1132_phoenix_interpolated.ecsv',
#  'interpolated_models/LHS2686_phoenix_interpolated.ecsv',
#  'interpolated_models/GJ163_phoenix_interpolated.ecsv',
#  'interpolated_models/L980-5_phoenix_interpolated.ecsv',
#  'interpolated_models/GJ15A_phoenix_interpolated.ecsv',
#  'interpolated_models/GJ699_phoenix_interpolated.ecsv']

# %%
specs = glob.glob('interpolated_models/*ecsv')
for sp in specs:
    data = Table.read(sp)
    print (data.meta)
    plt.plot(data['WAVELENGTH'], data['FLUX']*data.meta['NORMFAC'])
    plt.xscale('log')
    plt.yscale('log')
    plt.show()
    #plt.xlim(800, 1e7)
    #plt.ylim(1e-6, 1e25)
# Out:
# OrderedDict([('LOGG', 4.772484619083325), ('NORMFAC', <Quantity 1.40363859e-18>), ('TEFF', 3492)])
# OrderedDict([('LOGG', 4.87082792887964), ('NORMFAC', <Quantity 3.21328848e-18>), ('TEFF', 3404)])
# OrderedDict([('LOGG', 4.65331360755076), ('NORMFAC', <Quantity 7.77270093e-19>), ('TEFF', 4014)])
# OrderedDict([('LOGG', 5.083980902336978), ('NORMFAC', <Quantity 2.30537051e-18>), ('TEFF', 3248)])
# OrderedDict([('LOGG', 4.707209872123922), ('NORMFAC', <Quantity 1.33139157e-18>), ('TEFF', 3621)])
# OrderedDict([('LOGG', 5.060992437402149), ('NORMFAC', <Quantity 1.62146753e-19>), ('TEFF', 3196)])
# OrderedDict([('LOGG', 5.113824503742217), ('NORMFAC', <Quantity 9.75113133e-20>), ('TEFF', 3119)])
# OrderedDict([('LOGG', 4.822076034503119), ('NORMFAC', <Quantity 3.77057481e-19>), ('TEFF', 3460)])
# OrderedDict([('LOGG', 5.007675594849958), ('NORMFAC', <Quantity 1.77091985e-19>), ('TEFF', 3278)])
# OrderedDict([('LOGG', 4.861538718661559), ('NORMFAC', <Quantity 5.93844811e-18>), ('TEFF', 3601)])
# OrderedDict([('LOGG', 5.101210290261985), ('NORMFAC', <Quantity 5.34414782e-18>), ('TEFF', 3223)])

# %%
data = Table.read('interpolated_models/GJ15A_phoenix_interpolated.ecsv')
print(data.meta)
plt.plot(data['WAVELENGTH'], data['FLUX']*data.meta['NORMFAC'])
plt.xscale('log')
plt.yscale('log')
# Out:
# OrderedDict([('LOGG', 4.861538718661559), ('NORMFAC', <Quantity 5.93844811e-18>), ('TEFF', 3601)])

# %%
plt.plot(data['WAVELENGTH'], data['FLUX'])
plt.xscale('log')
plt.yscale('log')
plt.xlim(800, 2000)
plt.ylim(1e2, 1e20)
# Out:
# (100.0, 1e+20)

# %%
"""def extract_spectrum(filepath):
    """
  #  Extracts the spectrum from the Lyon files, which is non-trivial. Adapts code by JSP. 
    """
    #nameout = unzip_file(filepath)
    wavemin, wavemax, DF = 0, 3000, 8
    """
 #   phoenixR = ascii.read(filepath,format="fixed_width_no_header",col_starts=(0,14),col_ends=(12,25),delimiter=" ",names=('Wave','Spec'))
 #   ph1, jj = np.unique(np.array(phoenixR['Wave']),return_index=True)
 #   phoenix = np.zeros((len(ph1),2))
 #   for kk in range(len(jj)):
  #      line = phoenixR['Spec'][jj[kk]]
        #if kk < 10:
         #   print(line)
  #      if line[-1] == '-':
   #         line = line[:-1]
 #       phoenix[kk,1] = np.float64(line.replace("D","E"))
   # phoenix[:,0] = ph1
    """     
    try:
        phoenixR = ascii.read(filepath,format="fixed_width_no_header",col_starts=(0,14),col_ends=(12,25),delimiter=" ",names=('Wave','Spec'))
        ph1, jj = np.unique(np.array(phoenixR['Wave']),return_index=True)
        phoenix = np.zeros((len(ph1),2))
        for kk in range(len(jj)):
            phoenix[kk,1] = np.float64(phoenixR['Spec'][jj[kk]].replace("D","E"))
        phoenix[:,0] = ph1
    except:
            try:
                print("File Badly Formatted --- trying again...")
                phoenixR = ascii.read(filepath,format="fixed_width_no_header",col_starts=(0,13),col_ends=(12,24),delimiter=" ",names=('Wave','Spec'))
                ph1, jj = np.unique(np.array(phoenixR['Wave']),return_index=True)
                phoenix = np.zeros((len(ph1),2))
                for kk in range(len(jj)):
                    phoenix[kk,1] = np.float64(phoenixR['Spec'][jj[kk]].replace("D","E"))
                phoenix[:,0] = ph1
            except:
                print("... and again ... ")
                phoenixR = ascii.read(filepath,format="no_header",delimiter=" ")
                temp = np.zeros(len(phoenixR['col1']))
                for kk in range(len(temp)):
                    temp[kk] = np.float64(phoenixR['col1'][kk].replace("D","E"))
                ph1, jj = np.unique(temp,return_index=True)
                phoenix = np.zeros((len(ph1),2))
                for kk in range(len(jj)):
                    phoenix[kk,0] = np.float64(phoenixR['col1'][jj[kk]].replace("D","E"))
                    phoenix[kk,1] = np.float64(phoenixR['col2'][jj[kk]].replace("D","E"))
    
    ind = np.where( (phoenix[:,0] <= wavemax) & (phoenix[:,0] >= wavemin))[0]  
    xraw = phoenix[ind,0]
    i = 0
    while i < 10:
        print (phoenix[ind,0][i], phoenix[ind,1][i])
        i+=1
    yraw = np.power(10.,phoenix[ind,1] + DF)
    return xraw, yraw

gj_specs =['lte040.0-4.5-0.0a+0.0.BT-Settl.spec.7','lte041.0-5.0-0.0a+0.0.BT-Settl.spec.7']
for sp in gj_specs:
    print(sp)
    filepath = repo+sp
    w, f = extract_spectrum(filepath)
    plt.plot(w,f)
    plt.xscale('log')
    plt.yscale('log')
    plt.show()"""
# Out:
#   File "<ipython-input-10-73bace39b648>", line 4
#     """
#     ^
# IndentationError: unexpected indent

# %%
    # 145.6500 -9.02815D+01 -8.25000D+01   3  20    618.6719 1000 128    891.3070    7 128      0.0000    0 129  1000  6.186719D+02 -1.659000D+00  1.240001D-04     7  8.913070D+02 -1.536133D+00  8.758349D-02   1   1  6.34802D+07  6.01154D+07
     #    145.7000-8.97833D+01-7.98488D+01   3  19    618.6719 1000 128    892.6923    7 128      0.0000    0 129  1000 6.186719D+02-1.659000D+00 1.240001D-04     7 8.926923D+02-1.389459D+00 8.758349D-02   1   1 2.10674D+07 2.07329D+07

# %%
for sp in gj_specs:
    print(sp)
    filepath = repo+sp
    w, f = extract_spectrum(filepath)
    mask = (w > 140) & (w < 150)
    plt.plot(w[mask],f[mask])
   # plt.xscale('log')
    #plt.yscale('log')
    plt.show()

# %% [markdown]
# Flux too big?
