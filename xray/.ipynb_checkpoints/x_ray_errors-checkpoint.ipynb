# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as fits
import os
import glob
from astropy.table import Table
from astropy.io import ascii
import astropy.units as u
import astropy.constants as const
from astropy.convolution import convolve, Box1DKernel
from scipy.interpolate import interp1d
from matplotlib.gridspec import GridSpec
from astropy.modeling import models, fitting



#matplotlib set up
# %matplotlib inline
from matplotlib import rcParams
rcParams["figure.figsize"] = (14, 5)
rcParams["font.size"] = 20

# %% [markdown]
# implementing errorbars for APEC models using an MC.

# %%
from  xspec import *

# %%
#doing trappist-1 as a test, and as I want to update the SED

kts = np.array([0.2, 0.4])
ktes = np.array([0, 0])
norms = np.array([0.35, 0.07])*1e-4
normes = np.array([0.2,0.02])*1e-4

# %%
mod = Model('apec*phabs', setPars={1:kts[0], 2:0.4, 4:norms[0], 5:1e-3})
Plot.xAxis = "angstrom"
Plot.perHz = False
Plot.area=True
fluxnum = mod.flux[0]
AllModels.setEnergies("0.1 2.5 2400")
Plot("model")
xVals = Plot.x()
yVals = Plot.model()
wx = xVals*u.AA
fx  = (yVals * (u.photon/u.s/u.cm**2/u.AA)).to(u.erg/u.s/u.cm**2/u.AA, equivalencies=u.spectral_density(wx))
plt.plot(wx, fx)
plt.xlim(5, 50)
plt.yscale('log')
plt.show()
# Out:
# Reading APEC data from 3.0.9
#
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      1.00000      +/-  0.0
#    2    1   apec       Abundanc            1.00000      frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                1.00000      +/-  0.0
#    5    2   phabs      nH         10^22    1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model apec<1>*phabs<2> Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   apec       kT         keV      0.200000     +/-  0.0
#    2    1   apec       Abundanc            0.400000     frozen
#    3    1   apec       Redshift            0.0          frozen
#    4    1   apec       norm                3.50000E-05  +/-  0.0
#    5    2   phabs      nH         10^22    1.00000E-03  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins

# %%
mod = Model('phabs*(apec+apec)', setPars={1:1e-3, 2:kts[0], 3:0.4, 5:norms[0], 6:kts[1], 7:0.4, 9:norms[1]})
Plot.xAxis = "angstrom"
Plot.perHz = False
Plot.area=True
fluxnum = mod.flux[0]
AllModels.setEnergies("0.1 2.5 2400")
Plot("model")
xVals = Plot.x()
yVals = Plot.model()
wx = xVals*u.AA
fx  = (yVals * (u.photon/u.s/u.cm**2/u.AA)).to(u.erg/u.s/u.cm**2/u.AA, equivalencies=u.spectral_density(wx))
plt.plot(wx, fx)
plt.xlim(5, 50)
plt.show()
# Out:
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.200000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.50000E-05  +/-  0.0
#    6    3   apec       kT         keV      0.400000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                7.00000E-06  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins

# %%
nsteps = 10
kt1s = np.random.normal(kts[0], ktes[0], nsteps)
plt.subplot(141)
plt.hist(kt1s, bins=100)

kt2s = np.random.normal(kts[1], ktes[1], nsteps)
plt.subplot(142)
plt.hist(kt2s, bins=100)

norm1s = np.random.normal(norms[0], normes[0], nsteps)
plt.subplot(143)
plt.hist(norm1s, bins=100)

norm2s = np.random.normal(norms[1], normes[1], nsteps)
plt.subplot(144)
plt.hist(norm2s, bins=100)
plt.axvline(0)

# %%
nsteps = 10
i = 0
kt1s = np.random.normal(kts[0], ktes[0], nsteps)
kt2s = np.random.normal(kts[1], ktes[1], nsteps)
norm1s = np.random.normal(norms[0], normes[0], nsteps)
norm2s = np.random.normal(norms[1], normes[1], nsteps)
# print(len(norm2s[norm2s < 0]))

fluxes = []

while i < nsteps:
    if kt1s[i] > 0 and kt2s[i] >0 and norm1s[i] > 0 and norm2s[i] > 0: #some small amount go below 0
        mod = Model('phabs*(apec+apec)', setPars={1:1e-3, 2:kt1s[i], 3:0.4, 5:norm1s[i], 6:kt2s[i], 7:0.4, 9:norm2s[i]})
        Plot.xAxis = "angstrom"
        Plot.perHz = False
        Plot.area=True
        fluxnum = mod.flux[0]
        AllModels.setEnergies("0.1 2.5 2400")
        Plot("model")
        xVals = Plot.x()
        yVals = Plot.model()
        wx = xVals*u.AA
        fx  = (yVals * (u.photon/u.s/u.cm**2/u.AA)).to(u.erg/u.s/u.cm**2/u.AA, equivalencies=u.spectral_density(wx))
        plt.plot(wx, fx, alpha=0.01, c='C0')
        fluxes.append(fx.value)
    i +=1
plt.xlim(5, 50)
plt.yscale('log')
plt.show()

# print(len(wx))

flux = np.mean(fluxes, axis=0)
flux_err = np.std(fluxes, axis=0)
print(len(flux))
plt.plot(wx, flux)
plt.plot(wx, flux+flux_err, c='C0', alpha=0.5)
plt.plot(wx, flux-flux_err, c='C0', alpha=0.5)
plt.yscale('log')
# Out:
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.200000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.13147E-05  +/-  0.0
#    6    3   apec       kT         keV      0.400000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                9.96861E-06  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.200000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.51810E-05  +/-  0.0
#    6    3   apec       kT         keV      0.400000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.05361E-05  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.200000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.62244E-05  +/-  0.0
#    6    3   apec       kT         keV      0.400000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                6.89152E-06  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.200000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                7.43595E-05  +/-  0.0
#    6    3   apec       kT         keV      0.400000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                8.19484E-06  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.200000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                3.59085E-05  +/-  0.0
#    6    3   apec       kT         keV      0.400000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                6.16324E-06  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.200000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                4.50256E-05  +/-  0.0
#    6    3   apec       kT         keV      0.400000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                3.55917E-06  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.200000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                4.77396E-05  +/-  0.0
#    6    3   apec       kT         keV      0.400000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                8.57825E-06  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.200000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.98002E-05  +/-  0.0
#    6    3   apec       kT         keV      0.400000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                7.72070E-06  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.200000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                6.26605E-05  +/-  0.0
#    6    3   apec       kT         keV      0.400000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                6.80796E-06  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000      +/-  0.0
#    2    2   apec       kT         keV      1.00000      +/-  0.0
#    3    2   apec       Abundanc            1.00000      frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                1.00000      +/-  0.0
#    6    3   apec       kT         keV      1.00000      +/-  0.0
#    7    3   apec       Abundanc            1.00000      frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                1.00000      +/-  0.0
# ________________________________________________________________________
#
#
# ========================================================================
# Model phabs<1>(apec<2> + apec<3>) Source No.: 1   Active/Off
# Model Model Component  Parameter  Unit     Value
#  par  comp
#    1    1   phabs      nH         10^22    1.00000E-03  +/-  0.0
#    2    2   apec       kT         keV      0.200000     +/-  0.0
#    3    2   apec       Abundanc            0.400000     frozen
#    4    2   apec       Redshift            0.0          frozen
#    5    2   apec       norm                2.48975E-05  +/-  0.0
#    6    3   apec       kT         keV      0.400000     +/-  0.0
#    7    3   apec       Abundanc            0.400000     frozen
#    8    3   apec       Redshift            0.0          frozen
#    9    3   apec       norm                6.54211E-06  +/-  0.0
# ________________________________________________________________________
#
#
# Models will now use energy array created from:
#    0.1 - 2.5   2400 linear bins
# 2400

# %% [markdown]
# Moving to a script as I don't know how to turn off the printout

# %%
xtab = Table.read('mega-muscles_x-ray_params.csv')

# %%
xtab
# Out:
# <Table length=12>
#    Star       fx     fxeu    fxel    kt1   ...  kt3el    abd      nh    tel
#   str10    float64 float64 float64 float64 ... float64 float64 float64  str6
# ---------- ------- ------- ------- ------- ... ------- ------- ------- ------
#     GJ1132    1.15    0.33    0.27   0.086 ...     0.0     0.4     0.1    xmm
#      GJ15A     8.5     0.7     0.6    0.45 ...     0.0   0.195    0.05    cxo
#      GJ163    1.97    0.34    0.34    0.51 ...     0.0   0.195    0.05    cxo
#      GJ649    12.5     3.2     1.5    0.14 ...     0.0     0.4     0.1    xmm
#      GJ674   134.0     2.0     2.0    0.12 ...    0.03     0.4     0.1    xmm
#     GJ676A     9.7     1.7     1.7    0.24 ...     0.0     0.4     0.1    xrt
#      GJ699     6.3    0.55    0.55    0.54 ...     0.0    0.19    0.05    cxo
#      GJ729   568.0     7.0     7.0    0.15 ...    0.03     0.4     0.1    xmm
#      GJ849    4.74    0.57    0.57    0.32 ...     0.0   0.195    0.05    cxo
#    L-980-5    0.81    0.33    0.33    0.43 ...     0.0     1.0    0.05 cxo-up
#   LHS-2686    15.3     0.7     0.7     0.9 ...     0.0    0.61    0.05    cxo
# TRAPPIST-1    1.15    0.23    0.22     0.2 ...     0.0     0.4     0.1    xmm

# %%
for x in xtab:
    if x['kt3'] =! 0.0:
        kt1, kt2, kt3, abd, nh = x['kt1'], x['kt2'], x['kt3']
        
        mod = Model('(apec+apec+apec)*phabs', setPars={1:x['kt1', 2:x['abd'], 4:norms[0], 5:1e-3})
        Plot.xAxis = "angstrom"
        Plot.perHz = False
        Plot.area=True
        fluxnum = mod.flux[0]
        norm = x['fx']*1e-14/fluxnum
        AllModels.setEnergies("0.1 2.5 2400")
        Plot("model")
        xVals = Plot.x()
        yVals = Plot.model()
        wx = xVals*u.AA
        fx  = (yVals * (u.photon/u.s/u.cm**2/u.AA)).to(u.erg/u.s/u.cm**2/u.AA, equivalencies=u.spectral_density(wx))
        plt.plot(wx, fx)
        plt.xlim(5, 50)
        plt.yscale('log')
        plt.show()

        
        
        
    
    mod = Model('apec*phabs', setPars={1:kts[0], 2:0.4, 4:norms[0], 5:1e-3})
    Plot.xAxis = "angstrom"
    Plot.perHz = False
    Plot.area=True
    fluxnum = mod.flux[0]
    AllModels.setEnergies("0.1 2.5 2400")
    Plot("model")
    xVals = Plot.x()
    yVals = Plot.model()
    wx = xVals*u.AA
    fx  = (yVals * (u.photon/u.s/u.cm**2/u.AA)).to(u.erg/u.s/u.cm**2/u.AA, equivalencies=u.spectral_density(wx))
    plt.plot(wx, fx)
    plt.xlim(5, 50)
    plt.yscale('log')
    plt.show()

    
    fluxnum = mod.flux[0]
    print('fluxnum:', fluxnum)
    norm = lx[i]*1e-14/fluxnum
    mod.setPars({4:norm})
